# %%
#description: This is a data cleaning project done on SAT results from 460 schools in the city of New York.
#74 (16%) of the schools had no entries. 
#I used Python's Pandas library to normalize text, and fill missing entries with averages.

# %%
import pandas as pd
import numpy as np

# %%
#setting df to read
df = pd.read_csv("SAT__College_Board__2010_School_Level_Results.csv",encoding="latin")
df.head()
# Out:
#       DBN                                     School Name  \
# 0  01M292  Henry Street School for International Studies
# 1  01M448            University Neighborhood High School
# 2  01M450                East Side Community High School
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#    Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                   31.0                  391.0             425.0
# 1                   60.0                  394.0             419.0
# 2                   69.0                  418.0             431.0
# 3                   26.0                  385.0             370.0
# 4                    NaN                    NaN               NaN
#
#    Writing Mean
# 0         385.0
# 1         387.0
# 2         402.0
# 3         378.0
# 4           NaN

# %%
#making copy
df_copy=df
df_copy
# Out:
#         DBN                                        SCHOOL_NAME  \
# 0    01M292     Henry Street School for International Studies
# 1    01M448               University Neighborhood High School
# 2    01M450                   East Side Community High School
# 3    01M458                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509                                  CMSP HIGH SCHOOL
# ..      ...                                                ...
# 455  75R025                        South Richmond High School
# 456  75X012                      PS12X LEWIS AND CLARK SCHOOL
# 457  75X754  P754 X - Jeffrey M. Rapport School for Career ...
# 458  76K460                              John Jay High School
# 459  79X490                                    PHOENIX SCHOOL
#
#      NUMBER_OF_TEST_TAKERS  CRITICAL_READING_MEAN  MATHEMATICS_MEAN  \
# 0                     31.0                  391.0             425.0
# 1                     60.0                  394.0             419.0
# ...

# %%
#count of total entries: 460
df.count()
# Out:
# DBN                      460
# School Name              460
# Number of Test Takers    386
# Critical Reading Mean    386
# Mathematics Mean         386
# Writing Mean             386
# dtype: int64

# %%
#count of non-entries: 74
#74/460=.16, only 84% available
df.isnull().sum()
# Out:
# DBN                       0
# School Name               0
# Number of Test Takers    74
# Critical Reading Mean    74
# Mathematics Mean         74
# Writing Mean             74
# dtype: int64

# %%
#reformatting header and school_name to remove spaces/case differences
df.columns=df.columns.str.replace(" ","_")
df.columns=df.columns.str.upper()
df['SCHOOL_NAME']=df['SCHOOL_NAME'].str.upper()
df.head()
# Out:
#       DBN                                     SCHOOL_NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                EAST SIDE COMMUNITY HIGH SCHOOL
# 3  01M458                   SATELLITE ACADEMY FORSYTH ST
# 4  01M509                               CMSP HIGH SCHOOL
#
#    NUMBER_OF_TEST_TAKERS  CRITICAL_READING_MEAN  MATHEMATICS_MEAN  \
# 0                   31.0                  391.0             425.0
# 1                   60.0                  394.0             419.0
# 2                   69.0                  418.0             431.0
# 3                   26.0                  385.0             370.0
# 4                    NaN                    NaN               NaN
#
#    WRITING_MEAN
# 0         385.0
# 1         387.0
# 2         402.0
# 3         378.0
# 4           NaN

# %%
#fills NaN's with average of column 
df_mean=df.fillna(df.mean())
round(df_mean,0)
# Out:
#         DBN                                        SCHOOL_NAME  \
# 0    01M292     HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448               UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                   EAST SIDE COMMUNITY HIGH SCHOOL
# 3    01M458                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509                                  CMSP HIGH SCHOOL
# ..      ...                                                ...
# 455  75R025                        SOUTH RICHMOND HIGH SCHOOL
# 456  75X012                      PS12X LEWIS AND CLARK SCHOOL
# 457  75X754  P754 X - JEFFREY M. RAPPORT SCHOOL FOR CAREER ...
# 458  76K460                              JOHN JAY HIGH SCHOOL
# 459  79X490                                    PHOENIX SCHOOL
#
#      NUMBER_OF_TEST_TAKERS  CRITICAL_READING_MEAN  MATHEMATICS_MEAN  \
# 0                     31.0                  391.0             425.0
# 1                     60.0                  394.0             419.0
# ...

# %%
df.plot.hist()
